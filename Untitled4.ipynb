# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.tree import export_graphviz
from sklearn import tree
from IPython.display import SVG,display
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Generated Values (20 March, 2025)

df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
np.random.seed(42)
df["Stock_Available"] = np.random.randint(1000, 10000, df.shape[0])  
df["Stock_Used"] = df["Sales"]  
df["Restock_Threshold"] = np.random.randint(500, 2000, df.shape[0])  
df["Reorder_Quantity"] = np.random.randint(2000, 7000, df.shape[0])  
df["Stock_Replenished"] = (df["Stock_Available"] < df["Restock_Threshold"]).astype(int) 
df["Date"] = pd.date_range(start="2025-01-01", periods=df.shape[0], freq='D') 

# Save the new dataset
df.to_csv("Advertising_Extended.csv", index=False)

print("New dataset with inventory data saved as 'Advertising_Extended.csv'")
# Out:
# New dataset with inventory data saved as 'Advertising_Extended.csv'

# %%
df.shape
# Out:
# (200, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TV                 200 non-null    float64
#  1   Radio              200 non-null    float64
#  2   Newspaper          200 non-null    float64
#  3   Sales              200 non-null    float64
#  4   Stock_Available    200 non-null    int32
#  5   Stock_Used         200 non-null    float64
#  6   Restock_Threshold  200 non-null    int32
#  7   Reorder_Quantity   200 non-null    int32
#  8   Stock_Replenished  200 non-null    int32
#  9   Date               200 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int32(4)
# memory usage: 12.6 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# TV                   0
# Radio                0
# Newspaper            0
# Sales                0
# Stock_Available      0
# Stock_Used           0
# Restock_Threshold    0
# Reorder_Quantity     0
# Stock_Replenished    0
# Date                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales', 'Stock_Available', 'Stock_Used',
#        'Restock_Threshold', 'Reorder_Quantity', 'Stock_Replenished', 'Date'],
#       dtype='object')

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales  Stock_Available  \
# count  200.000000  200.000000  200.000000  200.000000       200.000000
# mean   147.042500   23.264000   30.554000   14.022500      5720.335000
# min      0.700000    0.000000    0.300000    1.600000      1064.000000
# 25%     74.375000    9.975000   12.750000   10.375000      3546.250000
# 50%    149.750000   22.900000   25.750000   12.900000      6125.000000
# 75%    218.825000   36.525000   45.100000   17.400000      7970.500000
# max    296.400000   49.600000  114.000000   27.000000      9996.000000
# std     85.854236   14.846809   21.778621    5.217457      2588.799649
#
#        Stock_Used  Restock_Threshold  Reorder_Quantity  Stock_Replenished  \
# count  200.000000         200.000000        200.000000         200.000000
# mean    14.022500        1242.150000       4535.685000           0.025000
# min      1.600000         501.000000       2114.000000           0.000000
# 25%     10.375000         902.250000       3342.000000           0.000000
# 50%     12.900000        1290.500000       4648.500000           0.000000
# 75%     17.400000        1578.000000       5608.250000           0.000000
# max     27.000000        1996.000000       6992.000000           1.000000
# std      5.217457         417.093024       1365.521527           0.156517
#
#                       Date
# count                  200
# mean   2025-04-10 12:00:00
# min    2025-01-01 00:00:00
# 25%    2025-02-19 18:00:00
# 50%    2025-04-10 12:00:00
# 75%    2025-05-30 06:00:00
# max    2025-07-19 00:00:00
# std                    NaN

# %%
for i in df.columns:
  print("No. of unique values in",i,"is",df[i].nunique())
# Out:
# No. of unique values in TV is 190
# No. of unique values in Radio is 167
# No. of unique values in Newspaper is 172
# No. of unique values in Sales is 121
# No. of unique values in Stock_Available is 199
# No. of unique values in Stock_Used is 121
# No. of unique values in Restock_Threshold is 187
# No. of unique values in Reorder_Quantity is 191
# No. of unique values in Stock_Replenished is 2
# No. of unique values in Date is 200

# %%
df.drop(['Unnamed: 0'],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.drop(['Unnamed: 0'],axis = 1,inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4782, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4780 for axis, labels in axes.items():
#    4781     if labels is not None:
# -> 4782         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4784 if inplace:
#    4785     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4824, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4822         new_axis = axis.drop(labels, level=level, errors=errors)
#    4823     else:
# -> 4824         new_axis = axis.drop(labels, errors=errors)
#    4825     indexer = axis.get_indexer(new_axis)
#    4827 # Case for non-unique axis
#    4828 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7069, in Index.drop(self, labels, errors)
#    7067 if mask.any():
#    7068     if errors != "ignore":
# -> 7069         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7070     indexer = indexer[~mask]
#    7071 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales  Stock_Available  Stock_Used  \
# 0  230.1   37.8       69.2   22.1             8270        22.1
# 1   44.5   39.3       45.1   10.4             1860        10.4
# 2   17.2   45.9       69.3    9.3             6390         9.3
# 3  151.5   41.3       58.5   18.5             6191        18.5
# 4  180.8   10.8       58.4   12.9             6734        12.9
#
#    Restock_Threshold  Reorder_Quantity  Stock_Replenished       Date
# 0                988              2116                  0 2025-01-01
# 1               1428              4838                  0 2025-01-02
# 2               1050              3150                  0 2025-01-03
# 3                837              3931                  0 2025-01-04
# 4               1371              3012                  0 2025-01-05

# %%
dependent_variable = ['Sales']

# %%
dependent_variable
# Out:
# ['Sales']

# %%
fig, axs = plt.subplots(1,3, sharey = True, figsize = (16,6))
df.plot(kind = 'scatter', x ='TV', y = 'Sales', ax = axs[0])
axs[0].set_title("TV vs Sales")
axs[0].set_xlabel("TV AD")
axs[0].set_ylabel("Sales")

df.plot(kind = 'scatter', x ='Radio', y = 'Sales', ax = axs[1])
axs[1].set_title("Radio vs Sales")
axs[1].set_xlabel("Radio AD")
axs[1].set_ylabel("Sales")

df.plot(kind = 'scatter', x ='Newspaper', y = 'Sales', ax = axs[2])
axs[2].set_title("Newspaper vs Sales")
axs[2].set_xlabel("Newspaper AD")
axs[2].set_ylabel("Sales")

plt.show()

# %%
plt.figure()
sns.heatmap(df.corr(), annot = True, linewidth = 0.3, fmt = '.3f', square = True, cmap = 'coolwarm')
plt.title("Heatmap")
df.shape
# Out:
# (200, 10)

# %%
plt.figure()
sns.heatmap(df.corr(), annot = True, linewidth = .1, fmt = '.2f', square = True, cmap = 'coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df, kind = 'reg')

# %%
features = [i for i in df.columns if i not in ['Sales']]
features
# Out:
# ['TV',
#  'Radio',
#  'Newspaper',
#  'Stock_Available',
#  'Stock_Used',
#  'Restock_Threshold',
#  'Reorder_Quantity',
#  'Stock_Replenished',
#  'Date']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(X):
    vif = pd.DataFrame()
    vif['Variables'] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    
    return(vif)

# %%
continuous_variables = ['TV', 'Radio', 'Newspaper','Stock_Available','Stock_Used','Restock_Threshold',
                        'Reorder_Quantity','Stock_Replenished'
]
continuous_variables
# Out:
# ['TV',
#  'Radio',
#  'Newspaper',
#  'Stock_Available',
#  'Stock_Used',
#  'Restock_Threshold',
#  'Reorder_Quantity',
#  'Stock_Replenished']

# %%
continuous_feature_df = pd.DataFrame(df[continuous_variables])
continuous_feature_df
# Out:
#         TV  Radio  Newspaper  Stock_Available  Stock_Used  Restock_Threshold  \
# 0    230.1   37.8       69.2             8270        22.1                988
# 1     44.5   39.3       45.1             1860        10.4               1428
# 2     17.2   45.9       69.3             6390         9.3               1050
# 3    151.5   41.3       58.5             6191        18.5                837
# 4    180.8   10.8       58.4             6734        12.9               1371
# ..     ...    ...        ...              ...         ...                ...
# 195   38.2    3.7       13.8             7546         7.6                619
# 196   94.2    4.9        8.1             2986         9.7               1330
# 197  177.0    9.3        6.4             9338        12.8               1581
# 198  283.6   42.0       66.2             3911        25.5               1869
# 199  232.1    8.6        8.7             2734        13.4               1240
#
#      Reorder_Quantity  Stock_Replenished
# 0                2116                  0
# 1                4838                  0
# 2                3150                  0
# 3                3931                  0
# 4                3012                  0
# ..                ...                ...
# 195              2133                  0
# 196              4105                  0
# 197              5627                  0
# 198              6780                  0
# 199              3852                  0
#
# [200 rows x 8 columns]

# %%
calc_vif(df[[i for i in continuous_feature_df]])
# Out:
#            Variables        VIF
# 0                 TV  24.701317
# 1              Radio  13.509695
# 2          Newspaper   3.379616
# 3    Stock_Available   5.932469
# 4         Stock_Used  71.842214
# 5  Restock_Threshold   7.549871
# 6   Reorder_Quantity   7.790815
# 7  Stock_Replenished   1.181918

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales  Stock_Available  Stock_Used  \
# 0  230.1   37.8       69.2   22.1             8270        22.1
# 1   44.5   39.3       45.1   10.4             1860        10.4
# 2   17.2   45.9       69.3    9.3             6390         9.3
# 3  151.5   41.3       58.5   18.5             6191        18.5
# 4  180.8   10.8       58.4   12.9             6734        12.9
#
#    Restock_Threshold  Reorder_Quantity  Stock_Replenished       Date
# 0                988              2116                  0 2025-01-01
# 1               1428              4838                  0 2025-01-02
# 2               1050              3150                  0 2025-01-03
# 3                837              3931                  0 2025-01-04
# 4               1371              3012                  0 2025-01-05

# %%
plt.figure(figsize=(9,5))
sns.distplot(df[dependent_variable])
plt.xlabel('Sales Count')
plt.title('Sales Count Distribution')
plt.axvline(df[dependent_variable[0]].mean(), c='magenta', linestyle='dashed', linewidth=2)
plt.axvline(df[dependent_variable[0]].median(), c='cyan', linestyle='dashed', linewidth=2)
plt.show()

# %%
df[dependent_variable].skew()
# Out:
# Sales    0.407571
# dtype: float64

# %%
X = df.drop('Sales',axis=1)
y = df[dependent_variable]

# %%
features = [i for i in df.columns if i not in ['Sales']]
features
# Out:
# ['TV',
#  'Radio',
#  'Newspaper',
#  'Stock_Available',
#  'Stock_Used',
#  'Restock_Threshold',
#  'Reorder_Quantity',
#  'Stock_Replenished',
#  'Date']

# %%
df.dtypes
# Out:
# TV                          float64
# Radio                       float64
# Newspaper                   float64
# Sales                       float64
# Stock_Available               int32
# Stock_Used                  float64
# Restock_Threshold             int32
# Reorder_Quantity              int32
# Stock_Replenished             int32
# Date                 datetime64[ns]
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])  
df['Date'] = df['Date'].view('int64') // 10**9 

from sklearn.preprocessing import StandardScaler

features = ['TV', 'Radio', 'Newspaper', 'Sales', 'Stock_Available', 
            'Stock_Used', 'Restock_Threshold', 'Reorder_Quantity', 'Stock_Replenished', 'Date']

scaler = StandardScaler()
X = scaler.fit_transform(df[features])

X = scaler.fit_transform(df[features])

# %%
X
# Out:
# array([[ 0.96985227,  0.98152247,  1.77894547, ..., -1.77643263,
#         -0.16012815, -1.7234121 ],
#        [-1.19737623,  1.08280781,  0.66957876, ...,  0.22194717,
#         -0.16012815, -1.70609137],
#        [-1.51615499,  1.52846331,  1.78354865, ..., -1.0173126 ,
#         -0.16012815, -1.68877065],
#        ...,
#        [ 0.34981006, -0.942899  , -1.11185242, ...,  0.80119833,
#         -0.16012815,  1.68877065],
#        [ 1.59456522,  1.26512143,  1.64085003, ...,  1.64768323,
#         -0.16012815,  1.70609137],
#        [ 0.99320602, -0.99016549, -1.00597925, ..., -0.50193324,
#         -0.16012815,  1.7234121 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
y_train.value_counts()
# Out:
# Sales
# 9.7      3
# 13.4     3
# 11.9     3
# 19.6     2
# 11.6     2
#         ..
# 14.9     1
# 15.0     1
# 15.2     1
# 15.3     1
# 27.0     1
# Name: count, Length: 87, dtype: int64

# %%
def evaluate_model(model, y_test, y_pred):
    mse = mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test,y_pred)
    y_train_pred = model.predict(X_train) 
    r2_train = r2_score(y_train, y_train_pred)
    r2 = r2_score(y_test,y_pred)
    r2_adjusted = 1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))

    print("MSE :" , mse)
    print("RMSE :" ,rmse)
    print("MAE :" ,mae)
    print("Train R2 :" ,r2_train)
    print("Test R2 :" ,r2)
    print("Adjusted R2 : ", r2_adjusted)


    plt.figure(figsize=(12,4))
    plt.plot((y_pred)[:100])
    plt.plot((np.array(y_test)[:100]))
    plt.legend(["Predicted","Actual"])
    plt.title('Actual and Predicted Sales', fontsize=12)


    model_score = [mse,rmse,mae,r2_train,r2,r2_adjusted]
    return model_score

# %%
score = pd.DataFrame(index = ['MSE', 'RMSE', 'MAE', 'Train R2', 'Test R2', 'Adjusted R2'])

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred_li = reg.predict(X_test)

# %%
linear_score = evaluate_model(reg, y_test,y_pred_li)
score['Linear regression'] = linear_score
# Out:
# MSE : 2.0069114466888304e-29
# RMSE : 4.479856523024851e-15
# MAE : 3.58046925441613e-15
# Train R2 : 1.0
# Test R2 : 1.0
# Adjusted R2 :  1.0

# %%
score
# Out:
#              Linear regression
# MSE               2.006911e-29
# RMSE              4.479857e-15
# MAE               3.580469e-15
# Train R2          1.000000e+00
# Test R2           1.000000e+00
# Adjusted R2       1.000000e+00

# %%
reg = LinearRegression()

param_grid = {'fit_intercept': [True, False]}

grid_search = GridSearchCV(reg, param_grid, cv=5, scoring='r2', return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]},
#              return_train_score=True, scoring='r2')

# %%
print("Best parameters: ", grid_search.best_params_)
print("Best R2 score: ", grid_search.best_score_)
# Out:
# Best parameters:  {'fit_intercept': True}
# Best R2 score:  1.0

# %%
best_reg = grid_search.best_estimator_
best_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_li2 = best_reg.predict(X_test)

# %%
linear_score2 = evaluate_model(best_reg, y_test, y_pred_li2)
# Out:
# MSE : 2.0069114466888304e-29
# RMSE : 4.479856523024851e-15
# MAE : 3.58046925441613e-15
# Train R2 : 1.0
# Test R2 : 1.0
# Adjusted R2 :  1.0

# %%
score['Linear Regression Tuned'] = linear_score2
score
# Out:
#              Linear regression  Linear Regression Tuned
# MSE               2.006911e-29             2.006911e-29
# RMSE              4.479857e-15             4.479857e-15
# MAE               3.580469e-15             3.580469e-15
# Train R2          1.000000e+00             1.000000e+00
# Test R2           1.000000e+00             1.000000e+00
# Adjusted R2       1.000000e+00             1.000000e+00

# %%
dt = DecisionTreeRegressor(random_state = 1)
dt.fit(X_train, y_train)
y_pred_dt1 = dt.predict(X_test)

# %%
result = evaluate_model(dt, y_test, y_pred_dt1)
score['Decision Tree'] = result
# Out:
# MSE : 0.10524999999999998
# RMSE : 0.32442256395016666
# MAE : 0.20500000000000007
# Train R2 : 1.0
# Test R2 : 0.9960016693742654
# Adjusted R2 :  0.9954222011676371

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422

# %%
dt_model = DecisionTreeRegressor(random_state=1)

grid = {'max_depth' : [8,10,12,14,16],
        'min_samples_split' : np.arange(35,50),
        'min_samples_leaf' : np.arange(22,31,2)
}

dt_gridsearch = GridSearchCV(dt_model,
                            grid, 
                            cv = 6,
                            scoring = 'neg_root_mean_squared_error')

dt_gridsearch.fit(X_train, y_train)
dt_best_params = dt_gridsearch.best_params_

# %%
dt_best_params
# Out:
# {'max_depth': 8, 'min_samples_leaf': 30, 'min_samples_split': 35}

# %%
dt_model = DecisionTreeRegressor(max_depth=dt_best_params['max_depth'],
                                 min_samples_leaf=dt_best_params['min_samples_leaf'],
                                 min_samples_split=dt_best_params['min_samples_split'],
                                 random_state=1)

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=30, min_samples_split=35,
#                       random_state=1)

# %%
y_pred_dt = dt_model.predict(X_test)

# %%
result = evaluate_model(dt_model, y_test, y_pred_dt)
score['Decsion Tree Tuned'] = result
# Out:
# MSE : 5.66001433139976
# RMSE : 2.3790784626404737
# MAE : 1.875895616701328
# Train R2 : 0.8344735509421122
# Test R2 : 0.7849823406809279
# Adjusted R2 :  0.7538203610694681

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree  \
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422
#
#              Decsion Tree Tuned
# MSE                    5.660014
# RMSE                   2.379078
# MAE                    1.875896
# Train R2               0.834474
# Test R2                0.784982
# Adjusted R2            0.753820

# %%
     rf = RandomForestRegressor(random_state = 0)
rf.fit(X_train, y_train)
y_pred_rf1 = rf.predict(X_test)

# %%
result = evaluate_model(rf, y_test, y_pred_rf1)
score['Random Forest'] = result
# Out:
# MSE : 0.1331365624999992
# RMSE : 0.3648788326280372
# MAE : 0.14168749999999836
# Train R2 : 0.9994211675262423
# Test R2 : 0.9949422898313656
# Adjusted R2 :  0.9942092883576504

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree  \
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422
#
#              Decsion Tree Tuned  Random Forest
# MSE                    5.660014       0.133137
# RMSE                   2.379078       0.364879
# MAE                    1.875896       0.141687
# Train R2               0.834474       0.999421
# Test R2                0.784982       0.994942
# Adjusted R2            0.753820       0.994209

# %%
rf_model = RandomForestRegressor(random_state = 0)
rf_params = {'n_estimators':[300],                    
             'min_samples_leaf':np.arange(20,25)}

# %%
rf_gridsearch = GridSearchCV(rf_model,rf_params,cv=6,scoring='neg_root_mean_squared_error')
rf_gridsearch.fit(X_train,y_train)
rf_best_params = rf_gridsearch.best_params_

# %%
rf_best_params
# Out:
# {'min_samples_leaf': 20, 'n_estimators': 300}

# %%
rf_model = RandomForestRegressor(n_estimators=rf_best_params['n_estimators'],
                                 min_samples_leaf=rf_best_params['min_samples_leaf'],
                                 random_state=0)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=20, n_estimators=300, random_state=0)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
result = evaluate_model(rf_model, y_test,y_pred_rf)
score['Random forest tuned'] = result
# Out:
# MSE : 3.8121798413353054
# RMSE : 1.9524804330223915
# MAE : 1.3904573552523056
# Train R2 : 0.8741247119465273
# Test R2 : 0.8551795210411499
# Adjusted R2 :  0.8341910458297224

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree  \
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422
#
#              Decsion Tree Tuned  Random Forest  Random forest tuned
# MSE                    5.660014       0.133137             3.812180
# RMSE                   2.379078       0.364879             1.952480
# MAE                    1.875896       0.141687             1.390457
# Train R2               0.834474       0.999421             0.874125
# Test R2                0.784982       0.994942             0.855180
# Adjusted R2            0.753820       0.994209             0.834191

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(random_state=0, objective='reg:squarederror')
xgb_model.fit(X_train, y_train)
y_pred_xgb1 = xgb_model.predict(X_test)

# %%
result = evaluate_model(xgb_model, y_test, y_pred_xgb1)
score['Extreme Gradient Boost'] = result
# Out:
# MSE : 0.09866713432483379
# RMSE : 0.31411325079473135
# MAE : 0.1891069364547729
# Train R2 : 1.0
# Test R2 : 0.9962517619132996
# Adjusted R2 :  0.9957085390021836

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree  \
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422
#
#              Decsion Tree Tuned  Random Forest  Random forest tuned  \
# MSE                    5.660014       0.133137             3.812180
# RMSE                   2.379078       0.364879             1.952480
# MAE                    1.875896       0.141687             1.390457
# Train R2               0.834474       0.999421             0.874125
# Test R2                0.784982       0.994942             0.855180
# Adjusted R2            0.753820       0.994209             0.834191
#
#              Extreme Gradient Boost
# MSE                        0.098667
# RMSE                       0.314113
# MAE                        0.189107
# Train R2                   1.000000
# Test R2                    0.996252
# Adjusted R2                0.995709

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(random_state=0,
                             objective='reg:squarederror')
xgb_params = {'n_estimators':[500],
             'min_samples_leaf':np.arange(20,22)}

# %%
xgb_search = RandomizedSearchCV(xgb_model,xgb_params,cv=6,scoring='neg_root_mean_squared_error',n_iter=100, n_jobs=-1)
xgb_search.fit(X_train,y_train)
xgb_best_params = xgb_search.best_params_

# %%
xgb_best_params
# Out:
# {'n_estimators': 500, 'min_samples_leaf': 20}

# %%
xgb_model = xgb.XGBRegressor(n_estimators=xgb_best_params['n_estimators'],
                             min_samples_leaf=xgb_best_params['min_samples_leaf'],
                             random_state=0)

# %%
xgb_model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, min_samples_leaf=20, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
result = evaluate_model(xgb_model, y_test,y_pred_xgb)
score['Extreme Gradient Boosting Regressor Tuned'] = result
# Out:
# MSE : 0.09866713432483379
# RMSE : 0.31411325079473135
# MAE : 0.1891069364547729
# Train R2 : 1.0
# Test R2 : 0.9962517619132996
# Adjusted R2 :  0.9957085390021836

# %%
score
# Out:
#              Linear regression  Linear Regression Tuned  Decision Tree  \
# MSE               2.006911e-29             2.006911e-29       0.105250
# RMSE              4.479857e-15             4.479857e-15       0.324423
# MAE               3.580469e-15             3.580469e-15       0.205000
# Train R2          1.000000e+00             1.000000e+00       1.000000
# Test R2           1.000000e+00             1.000000e+00       0.996002
# Adjusted R2       1.000000e+00             1.000000e+00       0.995422
#
#              Decsion Tree Tuned  Random Forest  Random forest tuned  \
# MSE                    5.660014       0.133137             3.812180
# RMSE                   2.379078       0.364879             1.952480
# MAE                    1.875896       0.141687             1.390457
# Train R2               0.834474       0.999421             0.874125
# Test R2                0.784982       0.994942             0.855180
# Adjusted R2            0.753820       0.994209             0.834191
#
#              Extreme Gradient Boost  Extreme Gradient Boosting Regressor Tuned
# MSE                        0.098667                                   0.098667
# RMSE                       0.314113                                   0.314113
# MAE                        0.189107                                   0.189107
# Train R2                   1.000000                                   1.000000
# Test R2                    0.996252                                   0.996252
# Adjusted R2                0.995709                                   0.995709

# %%
import pickle
with open("Random_Forest_models.pkl","wb") as f:
    pickle.dump(rf,f)

# %%
with open("Random_Forest_model.pkl", "rb") as f:
    loaded_rf_model = pickle.load(f)

new_test_preds = loaded_rf_model.predict(X_test)

mse = mean_squared_error(y_test, new_test_preds)
mae = mean_absolute_error(y_test, new_test_preds)
r2 = r2_score(y_test, new_test_preds)
print("MSE:", mse)
print("MAE:", mae)
print("R2 Score:", r2)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[222], line 2
#       1 with open("Random_Forest_model.pkl", "rb") as f:
# ----> 2     loaded_rf_model = pickle.load(f)
#       4 new_test_preds = loaded_rf_model.predict(X_test)
#       6 mse = mean_squared_error(y_test, new_test_preds)
#
# UnpicklingError: invalid load key, '\x0e'.
